# %%
# Out:
# Jupyter ne peut pas être démarré. Erreur lors de la tentative de localisation de Jupyter : Les cellules en cours d’exécution avec Python 3.10.4 64-bit nécessitent notebook et jupyter package.
#
# Exécutez la commande suivante pour installer 'jupyter et notebook' dans l’environnement Python.
#
# Commande : 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Cliquez sur <a href='https://aka.ms/installJupyterForVSCode'>ici</a> pour plus d’informations.
